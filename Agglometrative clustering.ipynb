# %%
from sklearn.datasets.samples_generator import make_blobs
# %matplotlib inline
import numpy as np
from pandas import DataFrame
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns;sns.set()
import pandas as pd

# %%
X,y_true=make_blobs(n_samples=20,n_features=2,centers=4,cluster_std=1.6,random_state=0)

# %%
plt.scatter(X[:,0],X[:,1],s=50,c='r')
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram,linkage

# %%
Z =linkage(X,'ward')

# %%
plt.figure(figsize=(25,15))
plt.title('Heirachial clustering dendrogram')
plt.xlabel('sample index')
plt.xlabel('distance')
dendrogram(Z,leaf_rotation=90.,leaf_font_size=20.)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
cluster = AgglomerativeClustering(n_clusters=4,affinity='euclidean',linkage='ward')
cluster.fit_predict(X)
# Out:
# array([3, 3, 1, 3, 1, 2, 1, 2, 0, 0, 2, 3, 3, 3, 0, 2, 1, 0, 3, 0],
#       dtype=int64)

# %%
plt.scatter(X[:,0],X[:,1],c=cluster.labels_,cmap='rainbow')
